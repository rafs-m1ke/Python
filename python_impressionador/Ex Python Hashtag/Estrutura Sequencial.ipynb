# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = int(input("Informe um número: "))
print(f"O número informado foi {numero}")
# Out:
# O número informado foi 5

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
n1 = int(input("Informe o primeiro número: "))
n2 = int(input("Informe o segundo número: "))
soma = n1 + n2
print(f"A soma entre {n1} e {n2} é igual a {soma}")
# Out:
# A soma entre 2 e 2 é igual a 4

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
n1 = float(input("Nota da Av1: "))
n2 = float(input("Nota da Av2: "))
n3 = float(input("Nota da Av3: "))
n4 = float(input("Nota da Av4: "))

media = (n1+n2+n3+n4) / 4

print(f"A média foi de {media:.2f}")
# Out:
# A média foi de 7.58

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
medida_metro = float(input("Digite a medida em metros: "))
conversor = medida_metro * 100

print(f"A conversão de {medida_metro} m é {conversor} cm")
# Out:
# A conversão de 10.0 m é 1000.0 cm

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input("Digite a largura da sala: "))
comprimento = float(input("Digite o comprimento da sala: "))

area = largura * comprimento

print(f"A área da sala é de {area:.2f}m2")
# Out:
# A área da sala é de 25.00m2

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
rem_hora = float(input("Valor da hora trabalhada: "))
qtde_horas = int(input("Quantidade de horas trabalhadas no mês: "))
salario = rem_hora * qtde_horas

print(f"O salario no referido mês é de R$ {salario:.2f}")
# Out:
# O salario no referido mês é de R$ 1920.00

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
temp_f = float(input("Digite a temperatura em Fahrenheit: "))
conversor = 5/9 * (temp_f - 32)
print(f"A temperatura de {temp_f}F em celsius é: {conversor:.1f}ºC")
# Out:
# A temperatura de 70.0F em celsius é: 21.1ºC

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
temp_c = float(input("Digite a temperatura em Celsius: "))
conversor = 9/5 * temp_c + 32
print(f"A temperatura de {temp_c}ºC em Fahrenheit é: {conversor:.2f}F")
# Out:
# A temperatura de 70.0ºC em Fahrenheit é: 158.00F

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input("Digite sua altura: "))
peso_ideal = 72.7 * altura - 58
print(f"Seu peso ideal é de {peso_ideal:.2f} Kg")
# Out:
# Seu peso ideal é de 65.59 Kg

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input("Digite sua altura: "))
peso_ideal_h = 72.7 * altura - 58
peso_ideal_m = 62.1 * altura - 44.7
print(f"Peso ideal masculino: {peso_ideal_h:.2f} Kg")
print(f"Peso ideal feminino: {peso_ideal_m:.2f} Kg")
# Out:
# Peso ideal masculino: 65.59 Kg
# Peso ideal feminino: 60.87 Kg

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
salario_hora = float(input("Valor da hora trabalhada: "))
horas_trabalhadas_mes = int(input("Quantidade de horas trabalhadas no mês: "))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = horas_trabalhadas_mes * salario_hora

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desc_ir = salario_bruto * 0.11

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desc_inss = salario_bruto * 0.08

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desc_sind = salario_bruto * 0.05

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - desc_inss - desc_ir - desc_sind
print(f"Seu salario bruto é de R$ {salario_bruto:.2f}")
print(f"INSS: - R$ {desc_inss:.2f}")
print(f"IR: - R$ {desc_ir:.2f}")
print(f"Imposto Sindicado: - R$ {desc_sind:.2f}")
print(f"Seu salário líquido é de R$ {salario_liquido:.2f}")
# Out:
# Seu salario bruto é de R$ 2400.00
# INSS: - R$ 192.00
# IR: - R$ 264.00
# Imposto Sindicado: - R$ 120.00
# Seu salário líquido é de R$ 1824.00

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area_pintura = float(input("Informa a area a ser pintada: "))
qtde_latas = (area_pintura / 3) / 18
valor = qtde_latas * 80

print(f"Para pintura de {area_pintura:.2f}m2 será necessário {qtde_latas:.2f} lata(s) de tinta, que custarão R$ {valor:.2f}")
# Out:
# Para pintura de 25.00m2 será necessário 0.46 lata(s) de tinta, que custarão R$ 37.04

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tam = float(input("Informe o tamanho do arquivo: "))
vel = float(input("Informe a velocidade de download: "))
conv = vel / 8
tempo_min = (tam / conv) / 60

print(f"O tempo para para fazer o download de {tam} MB, em uma internet de {vel} Mbps é de {tempo_min:.1f} min")
# Out:
# O tempo para para fazer o download de 100.0 MB, em uma internet de 1.0 Mbps é de 13.3 min
